# %%
## Important libraries
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
## Using pandas for reading the dataset
df=pd.read_csv("Invistico_Airline.csv")

# %%
df.shape
# Out:
# (129880, 22)

# %%
## Top five records of the dataset
df.head()
# Out:
#   satisfaction   Customer Type  Age   Type of Travel     Class  \
# 0    satisfied  Loyal Customer   65  Personal Travel       Eco
# 1    satisfied  Loyal Customer   47  Personal Travel  Business
# 2    satisfied  Loyal Customer   15  Personal Travel       Eco
# 3    satisfied  Loyal Customer   60  Personal Travel       Eco
# 4    satisfied  Loyal Customer   70  Personal Travel       Eco
#
#    Flight Distance  Seat comfort  Departure/Arrival time convenient  \
# 0              265             0                                  0
# 1             2464             0                                  0
# 2             2138             0                                  0
# 3              623             0                                  0
# 4              354             0                                  0
#
#    Food and drink  Gate location  ...  Online support  Ease of Online booking  \
# 0               0              2  ...               2                       3
# ...

# %%
## Last five records of the dataset
df.tail()
# Out:
#         satisfaction      Customer Type  Age   Type of Travel     Class  \
# 129875     satisfied  disloyal Customer   29  Personal Travel       Eco
# 129876  dissatisfied  disloyal Customer   63  Personal Travel  Business
# 129877  dissatisfied  disloyal Customer   69  Personal Travel       Eco
# 129878  dissatisfied  disloyal Customer   66  Personal Travel       Eco
# 129879  dissatisfied  disloyal Customer   38  Personal Travel       Eco
#
#         Flight Distance  Seat comfort  Departure/Arrival time convenient  \
# 129875             1731             5                                  5
# 129876             2087             2                                  3
# 129877             2320             3                                  0
# 129878             2450             3                                  2
# 129879             4307             3                                  4
#
#         Food and drink  Gate location  ...  Online support  \
# ...

# %%
## Column names in df
df.columns
# Out:
# Index(['satisfaction', 'Customer Type', 'Age', 'Type of Travel', 'Class',
#        'Flight Distance', 'Seat comfort', 'Departure/Arrival time convenient',
#        'Food and drink', 'Gate location', 'Inflight wifi service',
#        'Inflight entertainment', 'Online support', 'Ease of Online booking',
#        'On-board service', 'Leg room service', 'Baggage handling',
#        'Checkin service', 'Cleanliness', 'Online boarding',
#        'Departure Delay in Minutes', 'Arrival Delay in Minutes'],
#       dtype='object')

# %%
## Data columns informations
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129880 entries, 0 to 129879
# Data columns (total 22 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   satisfaction                       129880 non-null  object
#  1   Customer Type                      129880 non-null  object
#  2   Age                                129880 non-null  int64
#  3   Type of Travel                     129880 non-null  object
#  4   Class                              129880 non-null  object
#  5   Flight Distance                    129880 non-null  int64
#  6   Seat comfort                       129880 non-null  int64
#  7   Departure/Arrival time convenient  129880 non-null  int64
#  8   Food and drink                     129880 non-null  int64
#  9   Gate location                      129880 non-null  int64
#  10  Inflight wifi service              129880 non-null  int64
# ...

# %%
## Checking the null values in each column
df.isna().sum()
# Out:
# satisfaction                           0
# Customer Type                          0
# Age                                    0
# Type of Travel                         0
# Class                                  0
# Flight Distance                        0
# Seat comfort                           0
# Departure/Arrival time convenient      0
# Food and drink                         0
# Gate location                          0
# Inflight wifi service                  0
# Inflight entertainment                 0
# Online support                         0
# Ease of Online booking                 0
# On-board service                       0
# Leg room service                       0
# Baggage handling                       0
# Checkin service                        0
# Cleanliness                            0
# Online boarding                        0
# Departure Delay in Minutes             0
# Arrival Delay in Minutes             393
# dtype: int64

# %% [markdown]
# ## Insights from the above code
# 1- From the output of the above code we can see that there is only one column is available in df which have null values present
#
# 2- Arraival Delay in Minutes column have 393 null values

# %% [markdown]
# ## Code for checking the unique values present in each column

# %%
df['satisfaction'].unique()
# Out:
# array(['satisfied', 'dissatisfied'], dtype=object)

# %%
df['Customer Type'].unique()
# Out:
# array(['Loyal Customer', 'disloyal Customer'], dtype=object)

# %%
df['Age'].unique()
# Out:
# array([65, 47, 15, 60, 70, 30, 66, 10, 56, 22, 58, 34, 62, 35, 13, 52, 55,
#        28,  9, 25, 53, 16, 64, 42, 21, 20, 26, 48, 57, 31, 17, 33, 32, 38,
#        29, 24, 37,  7, 39, 11, 49,  8, 40, 45, 67, 59, 44, 69, 51, 18, 23,
#        12, 46, 41, 54, 27, 63, 61, 36, 50, 68, 19, 14, 43, 72, 71, 80, 77,
#        85, 78, 75, 79, 74, 73, 76], dtype=int64)

# %%
df['Type of Travel'].unique()
# Out:
# array(['Personal Travel', 'Business travel'], dtype=object)

# %%
df['Class'].unique()
# Out:
# array(['Eco', 'Business', 'Eco Plus'], dtype=object)

# %%
df['Flight Distance'].unique()
# Out:
# array([ 265, 2464, 2138, ..., 5832, 5120, 4260], dtype=int64)

# %%
df['Seat comfort'].unique()
# Out:
# array([0, 1, 4, 5, 2, 3], dtype=int64)

# %%
df['Departure/Arrival time convenient'].unique()
# Out:
# array([0, 1, 2, 3, 4, 5], dtype=int64)

# %%
df['Food and drink'].unique()
# Out:
# array([0, 1, 2, 3, 4, 5], dtype=int64)

# %%
df['Gate location'].unique()
# Out:
# array([2, 3, 4, 1, 5, 0], dtype=int64)

# %%
df['Inflight wifi service'].unique()
# Out:
# array([2, 0, 3, 4, 5, 1], dtype=int64)

# %%
df['Inflight entertainment'].unique()
# Out:
# array([4, 2, 0, 3, 5, 1], dtype=int64)

# %%
df['Online support'].unique()
# Out:
# array([2, 3, 4, 5, 1, 0], dtype=int64)

# %%
df['Ease of Online booking'].unique()
# Out:
# array([3, 2, 1, 5, 4, 0], dtype=int64)

# %%
df['On-board service'].unique()
# Out:
# array([3, 4, 1, 2, 5, 0], dtype=int64)

# %%
df['Leg room service'].unique()
# Out:
# array([0, 4, 3, 2, 5, 1], dtype=int64)

# %%
df['Baggage handling'].unique()
# Out:
# array([3, 4, 1, 2, 5], dtype=int64)

# %%
df['Checkin service'].unique()
# Out:
# array([5, 2, 4, 3, 1, 0], dtype=int64)

# %%
df['Cleanliness'].unique()
# Out:
# array([3, 4, 1, 2, 5, 0], dtype=int64)

# %%
df['Online boarding'].unique()
# Out:
# array([2, 3, 5, 4, 1, 0], dtype=int64)

# %%
df['Departure Delay in Minutes'].unique()
# Out:
# array([   0,  310,   17,   30,   47,   40,    5,    2,   34,    4,   13,
#         427,   15,   10,   16,   11,    9,    1,   19,   35,   14,    6,
#          27,   20,    3,   90,   12,   68,   93,    7,   29,   66,   97,
#         151,   64,   31,  140,   32,    8,   23,   24,   37,   80,   18,
#          89,  127,   84,  158,   26,   25,   72,  180,  143,  106,  178,
#          94,   70,   77,   21,   60,  129,   61,   38,   33,   45,  244,
#         122,   57,   95,  293,   44,  184,  186,  145,  101,  165,   39,
#          98,   46,   83,  205,   62,   96,   54,  265,   52,  201,   22,
#          43,   67,  315,   28,  103,   65,   58,   87,   53,   48,  231,
#         179,  155,  159,   41,  108,   36,  236,  173,  115,  132,   42,
#          59,   49,   86,  156,  185,  120,   76,   50,  138,   82,   78,
#          75,   92,   51,  177,  154,  232,   71,   73,  119,  110,  105,
#          85,   74,  161,  102,  162,   99,  111,  113,  148,   79,  214,
# ...

# %%
df['Arrival Delay in Minutes'].unique()
# Out:
# array([0.000e+00, 3.050e+02, 1.500e+01, 2.600e+01, 4.800e+01, 2.300e+01,
#        1.900e+01, 2.000e+00, 4.400e+02, 5.000e+00, 1.000e+00, 7.000e+00,
#        8.000e+00, 4.500e+01, 6.900e+01, 1.300e+01, 3.000e+00, 1.200e+01,
#        1.000e+01, 6.000e+00, 8.000e+01,       nan, 4.000e+00, 8.600e+01,
#        5.700e+01, 1.400e+01, 9.000e+00, 9.600e+01, 2.140e+02, 5.000e+01,
#        2.400e+01, 1.370e+02, 1.800e+01, 2.700e+01, 1.600e+01, 1.210e+02,
#        7.500e+01, 1.700e+01, 3.700e+01, 5.300e+01, 5.900e+01, 7.600e+01,
#        4.400e+01, 1.310e+02, 3.600e+01, 3.300e+01, 2.220e+02, 3.200e+01,
#        2.900e+01, 2.800e+01, 6.100e+01, 3.500e+01, 4.100e+01, 6.300e+01,
#        1.750e+02, 3.800e+01, 1.420e+02, 9.000e+01, 1.630e+02, 8.400e+01,
#        7.200e+01, 7.400e+01, 1.100e+01, 1.180e+02, 5.600e+01, 1.190e+02,
#        5.200e+01, 2.500e+01, 2.360e+02, 1.120e+02, 6.500e+01, 9.300e+01,
#        3.020e+02, 3.400e+01, 2.000e+01, 1.240e+02, 1.950e+02, 1.360e+02,
# ...

# %% [markdown]
# ## Exploratory Data analysis

# %%
df.describe()
# Out:
#                  Age  Flight Distance   Seat comfort  \
# count  129880.000000    129880.000000  129880.000000
# mean       39.427957      1981.409055       2.838597
# std        15.119360      1027.115606       1.392983
# min         7.000000        50.000000       0.000000
# 25%        27.000000      1359.000000       2.000000
# 50%        40.000000      1925.000000       3.000000
# 75%        51.000000      2544.000000       4.000000
# max        85.000000      6951.000000       5.000000
#
#        Departure/Arrival time convenient  Food and drink  Gate location  \
# count                      129880.000000   129880.000000  129880.000000
# mean                            2.990645        2.851994       2.990422
# std                             1.527224        1.443729       1.305970
# min                             0.000000        0.000000       0.000000
# 25%                             2.000000        2.000000       2.000000
# ...

# %% [markdown]
# ## Insights from the above code
# 1- Minimum age is 7 year and maximum age is 85 years.
#
# 2- Minimum flight distance is 50 and maximum flight distance is 6951.
#
# 3- Minimum and maximum value of Seat comfort, Departure/Arrival time convenient,Food and drink, Gate location, Inflight wifi
# service,Inflight entertainment,Online support,Ease of Online booking, On-board service, Leg room service, Checkin service, Cleanliness and Online boarding is 0 and 5 respectively.
#
# 4- Minimum and maximum value of Baggage handling is 1 and 5 respectively.
#
# 5- Maximum time delay in departure is 1592 minutes.
#
# 6- Maximum time delay in arrival is 1584 minutes.

# %%
## Pie chart of Airline Customer satification
plt.figure(figsize=(5.5,5.5),facecolor='lightgrey')
plt.title('Airline Customer satisfaction',ha='center',
          weight='bold',fontsize=10)
plt.pie(df['satisfaction'].value_counts(),
        autopct='%1.1f%%',
        textprops={'weight':'bold','fontsize':12},
        colors=['#01733F','#970E02'])
plt.legend(df['satisfaction'].unique(),loc='lower left')
plt.show()

# %% [markdown]
# ## Insight from the above graph
#
# 1- In the given dataset 54.7% customers are satisfied and 45.3% customers are dissatisfied from the airline services

# %%
## Pie charts of Airline Customer Type, Type of Travel and Class
fig,ax=plt.subplots(1,3,figsize=(24.5,24.5),facecolor='lightgrey')
ax[0].set_title('Airline Customer Types',
                ha='center',
                weight='bold',fontsize=15)
ax[0].pie(df['Customer Type'].value_counts(),
          autopct='%1.1f%%',
          textprops={'weight':'bold','fontsize':15,'color':'white'},
          colors=['#6E0297','#02976C'])
ax[0].legend(df['Customer Type'].unique(),loc='lower left')
ax[1].set_title('Types of Travel',
                ha='center',
                weight='bold',
                fontsize=18)
ax[1].pie(df['Type of Travel'].value_counts(),
          autopct='%1.1f%%',
          textprops={'weight':'bold','fontsize':15,'color':'white'},
          colors=['#6E0297','#02976C'])
ax[1].legend(df['Type of Travel'].unique(),loc='lower left')
ax[2].set_title('Class',
                ha='center',
                weight='bold',
                fontsize=18)
ax[2].pie(df['Class'].value_counts(),
          autopct='%1.1f%%',
          textprops={'weight':'bold','fontsize':15,'color':'white'},
          colors=['#6E0297','#02976C','#024397'])
ax[2].legend(df['Class'].unique(),loc='lower left')

# %% [markdown]
# ## Insights from the above graphs
# 1- In the given dataset 81.7% customers are loyal and 18.3% customers are disloyal
#
# 2- In the given dataset 69.1% customers are personal traveller and 30.9% customers are business traveller
#
# 3- In the given dataset 47.9%,44.9% and 7.2% customers are preffered eco,business and eco plus travel class respectively

# %%
## Pie charts of Airline Loyal customer satifaction and Airline Disloyal customer satisfaction
fig,ax=plt.subplots(1,2,figsize=(16.5,10.5),facecolor='lightgrey')
ax[0].set_title('Airline Loyal Customer satisfaction',
                ha='center',
                weight='bold')
ax[0].pie(df[df['Customer Type']=='Loyal Customer']['satisfaction'].value_counts(),
          autopct='%1.1f%%',
          textprops={'weight':'bold','fontsize':12},
          colors=['#01733F','#970E02'])
ax[0].legend(df[df['Customer Type']=='Loyal Customer']['satisfaction'].unique(),loc='lower center')
ax[1].set_title('Airline Disloyal Customer satisfaction',
                ha='center',
                weight='bold')
ax[1].pie(df[df['Customer Type']=='disloyal Customer']['satisfaction'].value_counts(),
          autopct='%1.1f%%',
          textprops={'weight':'bold','fontsize':12},
          colors=['#01733F','#970E02'])
ax[1].legend(df[df['Customer Type']=='disloyal Customer']['satisfaction'].unique(),loc='lower center')
plt.show()

# %% [markdown]
# ## Insights from the above graphs
#
# 1- In the given dataset 61.6% of loyal customers are satified and 38.4% of loyal customers are dissatisfied from the airline services
#
# 2- In the given dataset 76.0% of disloyal customers are satified and 24.0% of disloyal customers are dissatisfied from the airline services
#
# 3- From the above two graph we can conclude that percentage of disloyal customers are more satisfied than those of the loyal customers from the airline services

# %%
## Pie charts of Airline Personal Traveller v/s satification and Airline Business Traveller v/s satisfaction
fig,ax=plt.subplots(1,2,figsize=(16.5,10.5),facecolor='lightgrey')
ax[0].set_title('Airline Personal travel',
                ha='center',
                weight='bold')
ax[0].pie(df[df['Type of Travel']=='Personal Travel']['satisfaction'].value_counts(),
          autopct='%1.1f%%',
          textprops={'weight':'bold','fontsize':12},
          colors=['#01733F','#970E02'])
ax[0].legend(df[df['Type of Travel']=='Personal Travel']['satisfaction'].unique(),loc='lower center')
ax[1].set_title('Airline Business travel',ha='center',weight='bold')
ax[1].pie(df[df['Type of Travel']=='Business travel']['satisfaction'].value_counts(),
          autopct='%1.1f%%',
          textprops={'weight':'bold','fontsize':12},
          colors=['#01733F','#970E02'])
ax[1].legend(df[df['Type of Travel']=='Business travel']['satisfaction'].unique(),loc='lower center')
plt.show()

# %% [markdown]
# ## Insights from the above graphs
#
# 1- In the given dataset 53.4% of personal travellers are satisfied and 46.6% of personal traveller are dissatisfied from the Airline Services
#
# 2- In the given dataset 58.4% of Business travellers are satisfied and 41.6% of Business traveller are dissatisfied from the Airline Services
#
# 3- In the given dataset almost same rate of satisfication and dissatisfication shown the personal and business traveller

# %%
## Pie charts of Airline Loyal customer type of type and Airline Disloyal customer type of type
fig,ax=plt.subplots(1,2,figsize=(16.5,10.5),facecolor='lightgrey')
ax[0].set_title('Airline Loyal Customer type of travel',
                ha='center',
                weight='bold')
ax[0].pie(df[df['Customer Type']=='Loyal Customer']['Type of Travel'].value_counts(),
          autopct='%1.1f%%',
          textprops={'weight':'bold','fontsize':12},
          colors=['#01733F','#970E02'])
ax[0].legend(df[df['Customer Type']=='Loyal Customer']['Type of Travel'].unique(),loc='lower center')
ax[1].set_title('Airline Disloyal Customer type of travel',
                ha='center',
                weight='bold')
ax[1].pie(df[df['Customer Type']=='disloyal Customer']['Type of Travel'].value_counts(),
          autopct='%1.1f%%',
          textprops={'weight':'bold','fontsize':12},
          colors=['#01733F','#970E02'])
ax[1].legend(df[df['Customer Type']=='disloyal Customer']['Type of Travel'].unique(),loc='lower center')
plt.show()

# %% [markdown]
# ## Insights from the above graphs
#
# 1- From the first piechart 62.3% and 37.7% of the loyal customers travel personal and business respectively
#
# 2- From the second piechart 99.2% and 0.8% of the disloyal customers travel business and personal respectively
#
# 3- From the above two graph we can conclude that in loyal customers the percentage of personal travller is more than the business traveller but for disloyal customer this condition is completely oppostise

# %%
## Pie charts of difference classes and satisfaction
fig,ax=plt.subplots(1,3,figsize=(24.5,24.5),facecolor='lightgrey')
ax[0].set_title('Airline Eco-Class',
                ha='center',
                weight='bold')
ax[0].pie(df[df['Class']=='Eco']['satisfaction'].value_counts(),
          autopct='%1.1f%%',
          textprops={'weight':'bold','fontsize':12},
          colors=['#01733F','#970E02'])
ax[0].legend(df[df['Class']=='Eco']['satisfaction'].unique(),loc='lower center')
ax[1].set_title('Airline Business-Class',
                ha='center',
                weight='bold')
ax[1].pie(df[df['Class']=='Business']['satisfaction'].value_counts(),
          autopct='%1.1f%%',
          textprops={'weight':'bold','fontsize':12},
          colors=['#01733F','#970E02'])
ax[1].legend(df[df['Class']=='Business']['satisfaction'].unique(),loc='lower center')
ax[2].set_title('Airline Eco_plus-Class',
                ha='center',
                weight='bold')
ax[2].pie(df[df['Class']=='Eco Plus']['satisfaction'].value_counts(),
          autopct='%1.1f%%',
          textprops={'weight':'bold','fontsize':12},
          colors=['#01733F','#970E02'])
ax[2].legend(df[df['Class']=='Eco Plus']['satisfaction'].unique(),loc='lower center')
plt.show()

# %% [markdown]
# ## Insights from the above graphs
# 1- In the given dataset 60.6% eco-class customers are satisfied and remaining are dissatisfied from the Airline services
#
# 2- In the given dataset 70.9% business-class customers are satisfied and remaining are dissatisfied from the Airline services
#
# 3- In the given dataset 57.3% eco_plus-class customers are satisfied and remaining are dissatisfied from the Airline services
#
# 4- From the above three graphs we can concluded that satisfaction rate of business class customer are more than the remaining two classes

# %%
## Pie charts of Airline customer type and classes
fig,ax=plt.subplots(1,2,figsize=(16.5,10.5),facecolor='lightgrey')
ax[0].set_title('Loyal Customer Airline class',
                ha='center',
                weight='bold')
ax[0].pie(df[df['Customer Type']=='Loyal Customer']['Class'].value_counts(),
          autopct='%1.1f%%',
          textprops={'weight':'bold','fontsize':12},
          colors=['#6E0297','#02976C','#024397'])
ax[0].legend(df[df['Customer Type']=='Loyal Customer']['Class'].unique(),loc='lower left')
ax[1].set_title('Disloyal Customer Airline class',
                ha='center',
                weight='bold')
ax[1].pie(df[df['Customer Type']=='disloyal Customer']['Class'].value_counts(),
          autopct='%1.1f%%',
          textprops={'weight':'bold','fontsize':12},
          colors=['#6E0297','#02976C','#024397'])
ax[1].legend(df[df['Customer Type']=='disloyal Customer']['Class'].unique(),loc='lower left')
plt.show()

# %% [markdown]
# ## Insights from the above graphs
#
# 1- First graph shows that 49.9% of loyal customers preffer Economic class, 42.1% preffer Business class and remaining 8% preffer Economic plus class
#
# 2- Second graph shows that 57.3% of disloyal customers preffer Economic class, 38.8% preffer Business class and remaining 3.8% preffer Economic plus class
#
# 3- From both the graph we can conclude that most of the customers preffer Economic class for travel with Airline

# %%
## Pie charts of Airline difference type of travel and classes
fig,ax=plt.subplots(1,2,figsize=(16.5,10.5),facecolor='lightgrey')
ax[0].set_title('Personal Travel Airline class',
                ha='center',
                weight='bold')
ax[0].pie(df[df['Type of Travel']=='Personal Travel']['Class'].value_counts(),
          autopct='%1.1f%%',
          textprops={'weight':'bold','fontsize':12},
          colors=['#6E0297','#02976C','#024397'])
ax[0].legend(df[df['Type of Travel']=='Business travel']['Class'].unique(),loc='lower left')
ax[1].set_title('Business Travel Airline class',
                ha='center',
                weight='bold')
ax[1].pie(df[df['Type of Travel']=='Business travel']['Class'].value_counts(),
          autopct='%1.1f%%',
          textprops={'weight':'bold','fontsize':12},
          colors=['#6E0297','#02976C','#024397'])
ax[1].legend(df[df['Type of Travel']=='Business travel']['Class'].unique(),loc='lower left')
plt.show()

# %% [markdown]
# ## Insights from the above graphs
#
# 1- First graph shows that 82.1% of personal traveller preffer Economic class, 11.2% preffer Business class and remaining 6.7% preffer Economic plus class
#
# 2- Second graph shows that 66.3% of business traveller preffer Economic class, 28.2% preffer Business class and remaining 5.5% preffer Economic plus class
#
# 3- From both the graph we can conclude that most of the customers preffer Economic class for travel with Airline

# %% [markdown]
# ### There are 393 values null present in Arrival Delay in Minutes and 393 is very small in comparision with overall dataset so in this case the best way to deal with null values is drop those values by using dropna clause.

# %%
df.dropna(inplace=True)
df['Arrival Delay in Minutes'].isna().sum()
df['Arrival Delay in Minutes']=df['Arrival Delay in Minutes'].astype(int)

# %%
df.isna().sum()
# Out:
# satisfaction                         0
# Customer Type                        0
# Age                                  0
# Type of Travel                       0
# Class                                0
# Flight Distance                      0
# Seat comfort                         0
# Departure/Arrival time convenient    0
# Food and drink                       0
# Gate location                        0
# Inflight wifi service                0
# Inflight entertainment               0
# Online support                       0
# Ease of Online booking               0
# On-board service                     0
# Leg room service                     0
# Baggage handling                     0
# Checkin service                      0
# Cleanliness                          0
# Online boarding                      0
# Departure Delay in Minutes           0
# Arrival Delay in Minutes             0
# dtype: int64

# %% [markdown]
# ### Insights from the above code
#
# 1- From output of the above code we can say that there is no null values present in any column of the dataframe

# %%
df=df.reset_index()

# %%
df.drop('index',axis=1,inplace=True)

# %% [markdown]
# ### Type of customers and Type of travel will never impact the satisfaction of the Airline services so these two columns are not useful for our machine learning model

# %%
df_copy=df.drop(['Customer Type','Type of Travel'],axis=1)

# %%
df_copy.head()
# Out:
#   satisfaction  Age     Class  Flight Distance  Seat comfort  \
# 0    satisfied   65       Eco              265             0
# 1    satisfied   47  Business             2464             0
# 2    satisfied   15       Eco             2138             0
# 3    satisfied   60       Eco              623             0
# 4    satisfied   70       Eco              354             0
#
#    Departure/Arrival time convenient  Food and drink  Gate location  \
# 0                                  0               0              2
# 1                                  0               0              3
# 2                                  0               0              3
# 3                                  0               0              3
# 4                                  0               0              3
#
#    Inflight wifi service  Inflight entertainment  Online support  \
# 0                      2                       4               2
# ...

# %% [markdown]
# ## Insights from the above code
# 1- There are only two columns present in df_copy i.e satisfaction and class which have categorical data
#
# 2- Satisfaction column is our dependent feature
#
# 3- Remaining columns are our independent features

# %%
## Replacement of categorical data with the numerical data in satisfaction column
from sklearn.preprocessing import LabelEncoder
lencoder=LabelEncoder()
df_copy['satisfaction']=lencoder.fit_transform(df[['satisfaction']])

# %%
df_copy['satisfaction'].unique()
# Out:
# array([1, 0])

# %% [markdown]
# ### Insights from the above code
# 1- By using the label encoder we encoded satisfied at 1 and dissatisfied as 0

# %%
## Replacement of categorical data with numerical data in class column
from sklearn.preprocessing import OneHotEncoder
ohencoder=OneHotEncoder()
df_copy[['Class_Business','Class_Eco','Class_Eco Plus']]=pd.DataFrame(ohencoder.fit_transform(df_copy[['Class']]).toarray(),
                                                                      columns=[ohencoder.get_feature_names_out()])

# %%
df_copy[['Class_Business','Class_Eco','Class_Eco Plus']]=df_copy[['Class_Business','Class_Eco','Class_Eco Plus']].astype(int)

# %%
df_copy.drop('Class',axis=1,inplace=True)

# %%
df_copy.head()
# Out:
#    satisfaction  Age  Flight Distance  Seat comfort  \
# 0             1   65              265             0
# 1             1   47             2464             0
# 2             1   15             2138             0
# 3             1   60              623             0
# 4             1   70              354             0
#
#    Departure/Arrival time convenient  Food and drink  Gate location  \
# 0                                  0               0              2
# 1                                  0               0              3
# 2                                  0               0              3
# 3                                  0               0              3
# 4                                  0               0              3
#
#    Inflight wifi service  Inflight entertainment  Online support  ...  \
# 0                      2                       4               2  ...
# 1                      0                       2               2  ...
# ...

# %% [markdown]
# ## Insights from the above codes
#
# 1- We have been successfully converted all the categorical features into numerical features by using feature scaling techniques

# %%
### Correlations
df_copy.corr()
# Out:
#                                    satisfaction       Age  Flight Distance  \
# satisfaction                           1.000000  0.117913        -0.039133
# Age                                    0.117913  1.000000        -0.249438
# Flight Distance                       -0.039133 -0.249438         1.000000
# Seat comfort                           0.242371  0.008475        -0.042476
# Departure/Arrival time convenient     -0.015624  0.038905         0.001381
# Food and drink                         0.120568  0.015496        -0.004806
# Gate location                         -0.012272 -0.000805        -0.002322
# Inflight wifi service                  0.227010  0.014037         0.012314
# Inflight entertainment                 0.523364  0.130254        -0.027344
# Online support                         0.389890  0.121287        -0.031860
# Ease of Online booking                 0.432017  0.071728        -0.022326
# ...

# %%
plt.figure(figsize=(20,20))
sns.heatmap(df_copy.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ## Insights from the above graph
#
# 1- The maximum positive correlation exist between seat comfort and food and drink.
#
# 2- Satisfaction is 52% and 43% positively correlated with flight entertainment and ease of online booking.
#
# 3- From the above heatmap we can see that Age and Flight distance feature do not have any positive or negative correlation with other features so we can remove these two features from our dataframe

# %%
df_copy=df_copy.drop(['Flight Distance','Age'],axis=1)

# %%
### Independent and dependent features
### Independent features
X=df_copy.drop('satisfaction',axis=1)

### Dependent features
y=df_copy['satisfaction']

# %% [markdown]
# ## Machine Learning Model Implementation

# %%
### Train test split for model selection
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.33,random_state=42)
X_train.shape,X_test.shape,y_train.shape,y_test.shape
# Out:
# ((86756, 19), (42731, 19), (86756,), (42731,))

# %%
### Standalization of independent variables
from sklearn.preprocessing import StandardScaler
stscaler=StandardScaler()
X_train_stscaled=stscaler.fit_transform(X_train)
X_test_stscaled=stscaler.transform(X_test)

# %%
### Logistic Regression
from sklearn.linear_model import LogisticRegression
clf = LogisticRegression()
clf.fit(X_train_stscaled,y_train)
# Out:
# LogisticRegression()

# %%
## Prediction of dependent variable
y_pred_lg=clf.predict(X_test_stscaled)

# %%
### Performance Metrix(Confusion metrix,accuracy,classification_Report)
import sklearn.metrics as metrics
print("Accuracy is :", "%.6f" % metrics.accuracy_score(y_test, y_pred_lg))
print("Precision is :", "%.6f" % metrics.precision_score(y_test, y_pred_lg))
print("Recall is :", "%.6f" % metrics.recall_score(y_test, y_pred_lg))
print("F1 Score is :", "%.6f" % metrics.f1_score(y_test, y_pred_lg))
# Out:
# Accuracy is : 0.814701
# Precision is : 0.826192
# Recall is : 0.836258
# F1 Score is : 0.831194

# %%
### Confusion metrics
cm = metrics.confusion_matrix(y_test, y_pred_lg, labels = clf.classes_)
disp = metrics.ConfusionMatrixDisplay(confusion_matrix = cm,display_labels = clf.classes_)
disp.plot()

# %% [markdown]
# ## Insights from the above code and graphs
#
# 1- For training and testing the data we used logistic regression
#
# 2- By logistice regression we got Accuracy, Precision, Recall, and F1 Score is 0.814701, 0.826192, 0.836258, and 0.831194 respectively
#
# 3- In confusion metrics we can see that the value of True Positve and True negative is greater than the value of false positive and false negative
#
# 4- Difference between the value of false positive and false negative is not huge.

# %%
## Define the parameters for hyperparameter tunning
parameter_lg={'penalty':('l1', 'l2', 'elasticnet', 'None'),
              'solver':('newton-cg', 'sag', 'saga','lbfgs'),
              'max_iter':[100,200]}

# %%
### Hyperperameter tunning
from sklearn.model_selection import GridSearchCV
gcv_clf_lg=GridSearchCV(clf,param_grid=parameter_lg,scoring='accuracy',cv=5)
gcv_clf_lg.fit(X_train_stscaled,y_train)
# Out:
# GridSearchCV(cv=5, estimator=LogisticRegression(),
#              param_grid={'max_iter': [100, 200],
#                          'penalty': ('l1', 'l2', 'elasticnet', 'None'),
#                          'solver': ('newton-cg', 'sag', 'saga', 'lbfgs')},
#              scoring='accuracy')

# %%
gcv_clf_lg.best_params_
# Out:
# {'max_iter': 200, 'penalty': 'l2', 'solver': 'sag'}

# %%
y_pred_gcv_lg=gcv_clf_lg.predict(X_test_stscaled)

# %%
### Performance Metrix(Confusion metrix,accuracy,classification_Report)
import sklearn.metrics as metrics
print("Accuracy is :", "%.6f" % metrics.accuracy_score(y_test, y_pred_gcv_lg))
print("Precision is :", "%.6f" % metrics.precision_score(y_test, y_pred_gcv_lg))
print("Recall is :", "%.6f" % metrics.recall_score(y_test, y_pred_gcv_lg))
print("F1 Score is :", "%.6f" % metrics.f1_score(y_test, y_pred_gcv_lg))
# Out:
# Accuracy is : 0.814725
# Precision is : 0.826199
# Recall is : 0.836300
# F1 Score is : 0.831219

# %%
### Confusion metrics
cm = metrics.confusion_matrix(y_test, y_pred_gcv_lg, labels = clf.classes_)
disp = metrics.ConfusionMatrixDisplay(confusion_matrix = cm,display_labels = clf.classes_)
disp.plot()

# %% [markdown]
# ## Insights from the above code and graphs
#
# 1- For hyperparameter tunning we used different parameters and out of them we got the best parameter for our model and i.e max_iter is 200 penalty is l2, and solver is saga
#
# 2- After hyperparameter tunning we got Accuracy, Precision, Recall, and F1 Score is 0.814725, 0.826199, 0.836300, and 0.831219 respectively
#
# 3- In confusion metrics we can see that the value of True Positve and True negative is greater than the value of false positive and false negative
#
# 4- Difference between the value of false positive and false negative is not huge.
